# %%
# Load libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv('../data/house_data.csv')

# Inspect
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area       51 non-null     int64
#  1   bedrooms   51 non-null     int64
#  2   bathrooms  51 non-null     int64
#  3   age        51 non-null     int64
#  4   price      51 non-null     int64
# dtypes: int64(5)
# memory usage: 2.1 KB
#               area   bedrooms  bathrooms        age         price
# count    51.000000  51.000000  51.000000  51.000000  5.100000e+01
# mean   3500.000000   5.137255   3.980392   1.431373  1.129216e+06
# std    1486.606875   1.800218   1.606116   2.647677  5.069274e+05
# min    1000.000000   2.000000   1.000000   0.000000  3.000000e+05
# 25%    2250.000000   4.000000   3.000000   0.000000  6.950000e+05
# 50%    3500.000000   5.000000   4.000000   0.000000  1.200000e+06
# 75%    4750.000000   7.000000   5.000000   1.500000  1.565000e+06
# max    6000.000000   8.000000   7.000000  10.000000  1.950000e+06

# %%
# Correlation heatmap
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# Scatter plot: Area vs Price
plt.scatter(df['area'], df['price'])
plt.xlabel("Area (sqft)")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show()
